# %%
from statsmodels.tsa.api import ExponentialSmoothing as HWES
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
import pandas as pd
from typing import *
import numpy as np

# %%
# create a pandas from the sales data
# the index is the date and the value is the quantity sold
original_sales = pd.read_csv("data/o_sales.csv", sep=",", header=0, index_col=0)
original_sales.index = pd.to_datetime(original_sales.index, format="%Y-%m")
original_sales = original_sales.asfreq('MS')

# # split the series into train and test sets, last 12 months are the test set
# train_series = original_sales[:-12]
# test_series = original_sales[-12:]

original_series = original_sales
train_series = original_sales[:-3]
test_series = original_sales[-3:]


plt.figure(figsize=(20, 6))
plt.plot(original_series, color="blue",)
# plt.plot(test_series, color="orange", label="Test Series")
plt.title("Sales Data")
plt.xlabel("Date")
plt.ylabel("Quantity Sold")
plt.legend()
plt.show()
# Out:
# C:\Users\virgo stevanus\AppData\Local\Temp\ipykernel_20120\918032528.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
